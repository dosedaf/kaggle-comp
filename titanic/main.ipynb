# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

df = pd.read_csv('train.csv')

x = df.drop(['Survived', 'PassengerId'], axis=1)
y = df['Survived']

# %%
le = LabelEncoder()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 4
#       1 le = LabelEncoder()
#       3 for i in x:
# ----> 4     le.fit(i)
#
# File ~/code/ml/from-scratch/titanic/.venv/lib64/python3.14/site-packages/sklearn/preprocessing/_label.py:103, in LabelEncoder.fit(self, y)
#      90 def fit(self, y):
#      91     """Fit label encoder.
#      92
#      93     Parameters
#    (...)    101         Fitted label encoder.
#     102     """
# --> 103     y = column_or_1d(y, warn=True)
#     104     self.classes_ = _unique(y)
#     105     return self
#
# File ~/code/ml/from-scratch/titanic/.venv/lib64/python3.14/site-packages/sklearn/utils/validation.py:1434, in column_or_1d(y, dtype, input_name, warn, device)
#    1421         warnings.warn(
#    1422             (
#    1423                 "A column-vector y was passed when a 1d array was"
#    (...)   1428             stacklevel=2,
#    1429         )
#    1430     return _asarray_with_order(
#    1431         xp.reshape(y, (-1,)), order="C", xp=xp, device=device
#    1432     )
# -> 1434 raise ValueError(
#    1435     "y should be a 1d array, got an array of shape {} instead.".format(shape)
#    1436 )
#
# ValueError: y should be a 1d array, got an array of shape () instead.
